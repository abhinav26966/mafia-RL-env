# %% [markdown]
# # Walkthrough — DECEIT Werewolf env (Phase 2)
#
# Interactive notebook for sanity-checking the env locally.
#
# 1. Install: `pip install -e ".[dev]"`
# 2. Start server: `uvicorn werewolf_env.server.app:app --port 8000` (in a separate shell)
# 3. Run cells below.
#
# Phase 0: cell content TBD.
